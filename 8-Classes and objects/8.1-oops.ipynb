# %% [markdown]
# ### Classes and Objects
#
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modelling real-world scenarios using classes and objects. This lesson covers the basics of creating classes.

# %%
### A class is a blue print of creating objects. Attributes and methods

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
print(bmw)
# Out:
# <class '__main__.Car'>
# ...

# %%
audi.doors = 4

print(audi.doors)
# Out:
# 4

# %%
print(bmw.doors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(bmw.doors)
#
# AttributeError: 'Car' object has no attribute 'doors'

# %%
### Instance Variable and Methods
class Dog:
    ## constructor
    def __init__(self, name, age):
        self.name=name
        self.age=age
        
## create objects
dog1=Dog("Buddy", 3)
print(dog1)

# %%
## Define a class with instance methods:

class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def bark(self):
        print(f"{self.name} says woof")
        
dog1 = Dog("Buddy", 3)
dog1.bark()
# Out:
# Buddy says woof

# %%
### Modelling a Bank Account

## Define a class for bank account

class BankAccount:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New amount is {self.balance}")
        
    def withdraw(self, amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New balance is {self.balance}")
    
    def get_balance(self):
        return self.balance

## create an account

account=BankAccount("Priyansh", 50000)
print(account.balance)
# Out:
# 50000

# %%
account.deposit(50000)
# Out:
# 50000 is deposited. New amount is <bound method BankAccount.deposit of <__main__.BankAccount object at 0x10d378a70>>
